# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
dt= pd.read_csv('Scholar Data1.csv')

# %%
dt.head()
# Out:
#                                          Date_of_Birth  \
# مولانا لال حسین اخترؒ     1917                    1996
# مولانا ادریس کاندھلویؒ    1899                    1974
# مولانا حبیب اللہ امرتسریؒ 1865 (or 1869)    1943-06-12
# مولانا انورشاہ کشمیریؒ    1875-11-26        1933-05-28
# مولانا اشرف علی تھانویؒ   1863-08-19        1943-07-20
#
#                                                        Date_of_Death  \
# مولانا لال حسین اخترؒ     1917              Deobandi/Jamaat-e-Islami
# مولانا ادریس کاندھلویؒ    1899            Deobandi (Tablighi Jamaat)
# مولانا حبیب اللہ امرتسریؒ 1865 (or 1869)                Ahl-i-Hadith
# مولانا انورشاہ کشمیریؒ    1875-11-26                        Deobandi
# مولانا اشرف علی تھانویؒ   1863-08-19                 Deobandi (Sufi)
#
#                                          Scholar_Name  \
# مولانا لال حسین اخترؒ     1917                     No
# مولانا ادریس کاندھلویؒ    1899                     No
# ...

# %%
dt.isnull().sum()
# Out:
# Scholar_Name                          314
# Date_of_Birth                         108
# Date_of_Death                          97
# Maslak                                  0
# Previously_Qadiyani?                    0
# Remarks                               122
# Mentioned_in_Ehtasab_e_Qadiyaniyat    321
# References                            350
# dtype: int64

# %%
dt.shape
# Out:
# (353, 8)

# %%
sns.heatmap(dt.isnull(), yticklabels=False)
plt.show()
