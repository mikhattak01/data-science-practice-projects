# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import pyarrow.parquet as pq

# %%
df = pq.read_table('samplefile.parquet').to_pandas()

# %%
df['JOB_DESCRIPTION'].head(2)
# Out:
# 0    Gerber Collision &amp; Glass, IL Belvidere\n  ...
# 1    Senior EUT Analyst | S2 | Technology Platforms...
# Name: JOB_DESCRIPTION, dtype: str

# %%
pd.set_option('display.max_columns', None)
